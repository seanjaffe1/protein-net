# %%
import numpy as np
import tensorflow as tf
from models import CNNModel
from config import config
import os
print("Hi")
config = config()
config.restore_file = 'model-step-620-val-4.10332e+06.ckpt'
# Out:
# Hi

# %%
sess = tf.Session()
model = CNNModel()
saver = tf.train.Saver()
os.getcwd()

# %%
print('Trying Model from '+ config.logdir + '/'+ config.restore_file)

saver.restore(sess, config.logdir + '/' + config.restore_file)
start_step = int(config.restore_file.split('step-')[1].split('-')[0])
print('Restored Model from '+ config.logdir + '/'+ config.restore_file)
# Out:
# Trying Model from ./train_model_test/model-step-620-val-4.10332e+06.ckpt
# INFO:tensorflow:Restoring parameters from ./train_model_test/model-step-620-val-4.10332e+06.ckpt
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~/tacc-work/jupyter_packages/envs/rosetta/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# ~/tacc-work/jupyter_packages/envs/rosetta/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# ...

# %%
dir(config)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'batch_size',
#  'checkpoint_every',
#  'data_dir',
#  'data_file',
#  'keep_prob',
#  'l2_reg',
#  'learning_rate',
#  'logdir',
#  'num_steps',
#  'restore_file',
#  'train_percent']
